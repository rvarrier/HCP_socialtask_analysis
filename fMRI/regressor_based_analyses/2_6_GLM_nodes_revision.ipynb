# %%
# import general packages, check folders
#%reset
import os
import numpy as np
import h5py
import pandas as pd
#import imagesc as imagesc #pip install imagesc
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import time
from pathlib import Path

# TO DO - REMOVE THE UNNECESSARY LIBRARY IMPORTS

# %matplotlib inline

working_dir = '/Users/f0053cz/Dropbox (Dartmouth College)/postdoc_Dartmouth/HCP/fMRIScipts/code'
#working_dir = os.getcwd()
print('current directory:\n',working_dir)
path = Path(working_dir)
parent_folder = path.parent
#print('parent folder:', parent_folder)
data_file_loc = os.path.join(parent_folder,'data') # to store data we extract later in this notebook
# Out:
# current directory:
#  /Users/f0053cz/Dropbox (Dartmouth College)/postdoc_Dartmouth/HCP/fMRIScipts/code

# %%
nodes_coaxbill_rand_all = np.load(os.path.join(data_file_loc,'nodes_coaxbill_rand_all.npy'))
len(np.where(nodes_coaxbill_rand_all)[0])
# Out:
# 70

# %%
shen268_lbl = pd.read_csv(os.path.join(data_file_loc,"shen_dictionary.csv"))
pd.set_option('display.max_colwidth', None)
shen268_lbl.head()
# Out:
#                                                                                                                             1  \
# 0  {'coords': [14.083200000000005, 56.6944, -16.684799999999996], 'name': '92.80% Frontal_Pole; 7.20% Frontal_Medial_Cortex'}
#
#                                                                                                                                             2  \
# 0  {'coords': [9.599999999999994, 17.61882352941177, -19.53411764705882], 'name': '60.56% Subcallosal_Cortex; 38.73% Frontal_Orbital_Cortex'}
#
#                                                                                                                                           3  \
# 0  {'coords': [5.270633397312864, 35.03262955854126, -17.5278310940499], 'name': '58.54% Frontal_Medial_Cortex; 34.55% Subcallosal_Cortex'}
#
#                                                                                                                                         4  \
# 0  {'coords': [15.647840531561457, 34.18604651162792, -22.544850498338867], 'name': '54.15% Frontal_Pole; 41.86% Frontal_Orbital_Cortex'}
#
#                                                                                                                                                                                                             5  \
# 0  {'coords': [8.283887468030684, 46.05882352941177, -1.6700767263427139], 'name': '47.25% Paracingulate_Gyrus; 25.03% Cingulate_Gyrus_anterior_division; 16.35% Frontal_Medial_Cortex; 10.86% Frontal_Pole'}
#
#                                                                                                         6  \
# 0  {'coords': [14.581460674157299, 64.75280898876406, 3.682584269662925], 'name': '100.00% Frontal_Pole'}
#
#                                                                                                          7  \
# 0  {'coords': [30.41914191419142, 54.79537953795381, -3.3267326732673297], 'name': '100.00% Frontal_Pole'}
#
#                                                                                                          8  \
# 0  {'coords': [44.469325153374236, 46.095092024539866, -4.917177914110425], 'name': '99.85% Frontal_Pole'}
#
#                                                                                                          9  \
# 0  {'coords': [28.814814814814817, 51.163163163163176, 18.73473473473473], 'name': '100.00% Frontal_Pole'}
#
#                                                                                                                                                      10  \
# 0  {'coords': [8.521081081081078, 53.28, 23.885405405405407], 'name': '48.54% Frontal_Pole; 32.43% Paracingulate_Gyrus; 19.03% Superior_Frontal_Gyrus'}
#
#    ...  \
# 0  ...
#
#                                                                                                                                                                                                                               259  \
# 0  {'coords': [-10.399527186761233, 10.877068557919614, -8.056737588652481], 'name': '20.66% Subcallosal_Cortex; 19.95% Left_Putamen; 19.83% Left_Accumbens; 14.40% Left_Caudate; 13.81% no_label; 5.67% Frontal_Orbital_Cortex'}
#
#                                                                                                                                                             260  \
# 0  {'coords': [-14.491582491582491, -3.54882154882155, 20.909090909090907], 'name': '55.03% Left_Caudate; 29.53% Left_Lateral_Ventrical; 11.07% Left_Thalamus'}
#
#                                                                                                         261  \
# 0  {'coords': [-24.77079107505071, 5.537525354969574, -0.07302231237322587], 'name': '96.96% Left_Putamen'}
#
#                                                                                                                                              262  \
# 0  {'coords': [-9.427230046948353, -25.539906103286384, -1.3755868544600958], 'name': '72.56% Left_Thalamus; 21.40% Brain-Stem; 5.58% no_label'}
#
#                                                                                                                                     263  \
# 0  {'coords': [-4.68474576271187, -10.2406779661017, 5.877966101694909], 'name': '82.71% Left_Thalamus; 13.90% Left_Lateral_Ventrical'}
#
#                                                                                                                                          264  \
# 0  {'coords': [-11.407792207792212, -25.563636363636363, 14.883116883116884], 'name': '61.82% Left_Thalamus; 31.43% Left_Lateral_Ventrical'}
#
#                                                                                                                        265  \
# 0  {'coords': [-4.821052631578951, -21.51157894736842, -15.890526315789472], 'name': '71.16% Brain-Stem; 25.89% no_label'}
#
#                                                                                                       266  \
# 0  {'coords': [-4.227272727272734, -37.89772727272728, -53.26704545454545], 'name': '100.00% Brain-Stem'}
#
#                                                                                           267  \
# 0  {'coords': [-6.9375, -33.13068181818181, -39.34659090909091], 'name': '99.15% Brain-Stem'}
#
#                                                                                                        268
# 0  {'coords': [-5.697885196374628, -18.966767371601208, -36.81570996978852], 'name': '100.00% Brain-Stem'}
#
# [1 rows x 268 columns]

# %%
glm_nodes = np.where(nodes_coaxbill_rand_all)[0]

# %%
roi_name = []
MNI_coord = np.array([glm_nodes.shape[0],3])
ind = -1
for n in glm_nodes:
    ind += 1
    #print(n, eval(shen268_lbl[str(n+1)][0])['name'], eval(shen268_lbl[str(n+1)][0])['coords'])
    roi_name.append(eval(shen268_lbl[str(n+1)][0])['name'])
    MNI_coord[ind,:], eval(shen268_lbl[str(n+1)][0])['coords'])
# Out:
# 8 100.00% Frontal_Pole [28.814814814814817, 51.163163163163176, 18.73473473473473]
# 9 48.54% Frontal_Pole; 32.43% Paracingulate_Gyrus; 19.03% Superior_Frontal_Gyrus [8.521081081081078, 53.28, 23.885405405405407]
# 11 56.57% Superior_Frontal_Gyrus; 41.14% Frontal_Pole [14.579047619047614, 36.74285714285713, 49.114285714285714]
# 12 33.82% Middle_Frontal_Gyrus; 33.82% Frontal_Pole; 26.94% Superior_Frontal_Gyrus; 5.42% no_label [24.029282576866763, 30.705710102489007, 36.395314787701324]
# 13 98.80% Middle_Frontal_Gyrus [40.58902275769746, 14.586345381526115, 48.28112449799197]
# 15 42.87% Inferior_Frontal_Gyrus_pars_triangularis; 25.98% Inferior_Frontal_Gyrus_pars_opercularis; 12.25% Frontal_Orbital_Cortex; 10.24% Frontal_Pole; 6.02% Frontal_Operculum_Cortex [53.604651162790695, 24.84566596194503, 0.9048625792811862]
# 18 56.48% Frontal_Pole; 27.04% Inferior_Frontal_Gyrus_pars_triangularis; 14.09% Middle_Frontal_Gyrus [48.17358490566038, 35.806289308176105, 15.182389937106919]
# 19 43.55% Frontal_Operculum_Cortex; 33.40% Insular_Cortex; 10.36% Inferior_Frontal_Gyrus_pars_triangularis; 6.98% Frontal_Orbital_Cortex; 5.71% Inferior_Frontal_Gyrus_pars_opercularis [37.05285412262157, 20.799154334038064, 6.0]
# 21 76.55% Middle_Frontal_Gyrus; 21.03% Inferior_Frontal_Gyrus_pars_opercularis [39.93448275862069, 17.64827586206897, 29.113793103448273]
# 28 80.29% Superior_Frontal_Gyrus; 18.49% Juxtapositional_Lobule_Cortex_(formerly_Supplementary_Motor_Cortex) [13.767184035476717, 6.3592017738359345, 65.3968957871397]
# 29 53.27% Superior_Frontal_Gyrus; 44.39% Middle_Frontal_Gyrus [25.250420168067222, 12.386554621848745, 49.41176470588235]
# 30 75.69% Precentral_Gyrus; 20.60% Middle_Frontal_Gyrus [39.824074074074076, 3.4768518518518476, 34.074074074074076]
# 42 65.82% Lateral_Occipital_Cortex_superior_division; 19.42% Superior_Parietal_Lobule; 11.12% Angular_Gyrus [31.57938144329897, -60.73539518900344, 49.282474226804126]
# 47 66.63% Lateral_Occipital_Cortex_superior_division; 33.37% Angular_Gyrus [47.79274611398964, -61.56476683937824, 34.71295336787564]
# 48 100.00% Lateral_Occipital_Cortex_superior_division [41.3992297817715, -75.33761232349165, 27.89473684210526]
# 49 35.64% Angular_Gyrus; 25.13% Middle_Temporal_Gyrus_temporooccipital_part; 22.21% Lateral_Occipital_Cortex_inferior_division; 16.62% Lateral_Occipital_Cortex_superior_division [48.86702127659574, -58.01329787234043, 14.295212765957444]
# 64 51.09% Middle_Temporal_Gyrus_temporooccipital_part; 26.64% Supramarginal_Gyrus_posterior_division; 12.90% Angular_Gyrus; 6.04% Superior_Temporal_Gyrus_posterior_division [59.240374609781476, -43.72736732570239, 8.616024973985432]
# 65 35.14% Inferior_Temporal_Gyrus_temporooccipital_part; 29.73% Lateral_Occipital_Cortex_inferior_division; 27.48% Temporal_Occipital_Fusiform_Cortex; 7.66% Occipital_Fusiform_Gyrus [46.513513513513516, -59.8018018018018, -14.716216216216218]
# 66 54.07% Occipital_Fusiform_Gyrus; 28.60% Lateral_Occipital_Cortex_inferior_division; 14.90% Temporal_Occipital_Fusiform_Cortex [36.57192374350087, -69.2790294627383, -17.4419410745234]
# 68 48.69% Middle_Temporal_Gyrus_temporooccipital_part; 29.07% Lateral_Occipital_Cortex_inferior_division; 22.09% Inferior_Temporal_Gyrus_temporooccipital_part [55.26453488372093, -56.28197674418604, -4.79651162790698]
# 69 54.11% Inferior_Temporal_Gyrus_temporooccipital_part; 17.25% Middle_Temporal_Gyrus_temporooccipital_part; 14.99% Middle_Temporal_Gyrus_posterior_division; 13.55% Inferior_Temporal_Gyrus_posterior_division [60.80082135523614, -43.37577002053388, -17.652977412731005]
# 70 65.90% Temporal_Occipital_Fusiform_Cortex; 17.05% Inferior_Temporal_Gyrus_temporooccipital_part; 9.84% Temporal_Fusiform_Cortex_posterior_division [41.678688524590164, -45.652459016393436, -22.583606557377053]
# 72 76.60% Lateral_Occipital_Cortex_superior_division; 17.79% Occipital_Pole; 5.61% Lateral_Occipital_Cortex_inferior_division [30.108974358974358, -83.00641025641025, 20.467948717948715]
# 73 95.78% Lateral_Occipital_Cortex_inferior_division [45.1231884057971, -74.23913043478261, 2.6062801932367137]
# 75 60.71% Occipital_Fusiform_Gyrus; 21.94% Lingual_Gyrus; 17.21% Occipital_Pole [18.03679369250986, -83.38764783180027, -11.250985545335084]
# 80 55.16% Occipital_Pole; 38.06% Lateral_Occipital_Cortex_inferior_division; 6.78% Occipital_Fusiform_Gyrus [30.998459167950692, -91.90446841294299, -10.795069337442214]
# 89 83.65% Precuneous_Cortex; 16.35% Cingulate_Gyrus_posterior_division [6.3299270072992755, -57.185401459854006, 38.08759124087591]
# 99 100.00% no_label [32.22514619883041, -78.47368421052632, -40.41228070175438]
# 101 55.82% no_label; 30.46% Lateral_Occipital_Cortex_inferior_division; 9.67% Occipital_Fusiform_Gyrus [38.87318087318087, -74.9106029106029, -29.59043659043659]
# 103 61.35% no_label; 38.65% Brain-Stem [23.47572815533981, -35.990291262135926, -42.9126213592233]
# 104 100.00% no_label [7.170454545454547, -68.14204545454545, -37.65340909090909]
# 106 97.80% no_label [45.83622047244094, -46.37165354330709, -42.52913385826771]
# 107 73.28% no_label; 26.72% Brain-Stem [16.186274509803923, -47.28431372549019, -52.55882352941177]
# 110 87.65% no_label; 10.29% Occipital_Fusiform_Gyrus [11.770588235294113, -84.15882352941176, -34.71176470588235]
# 111 100.00% no_label [19.7553017944535, -73.49429037520392, -50.127243066884176]
# 112 99.82% no_label [36.79225352112676, -57.12676056338029, -32.79225352112676]
# 113 79.25% no_label; 18.01% Occipital_Fusiform_Gyrus [22.98456260720411, -71.93481989708405, -29.118353344768437]
# 115 100.00% no_label [42.07073954983923, -64.0085744908896, -49.18327974276527]
# 116 87.58% no_label; 12.42% Brain-Stem [7.242424242424249, -53.7030303030303, -34.333333333333336]
# 118 49.05% no_label; 27.70% Temporal_Fusiform_Cortex_posterior_division; 10.78% Brain-Stem; 8.67% Temporal_Occipital_Fusiform_Cortex [30.309322033898304, -36.39830508474576, -31.093220338983052]
# 127 88.97% Right_Thalamus; 7.60% Right_Lateral_Ventricle [5.688212927756652, -9.832699619771859, 4.904942965779469]
# 144 78.35% Frontal_Pole; 21.65% Superior_Frontal_Gyrus [-10.034188034188034, 55.63247863247864, 30.350427350427353]
# 146 66.70% Middle_Frontal_Gyrus; 17.50% Inferior_Frontal_Gyrus_pars_triangularis; 8.86% Frontal_Pole; 6.14% Inferior_Frontal_Gyrus_pars_opercularis [-46.08873720136518, 28.209328782707615, 26.77133105802048]
# 148 97.89% Middle_Frontal_Gyrus [-39.36140350877193, 17.148538011695905, 46.74152046783625]
# 150 51.03% Frontal_Orbital_Cortex; 25.77% Inferior_Frontal_Gyrus_pars_triangularis; 11.73% Frontal_Pole; 8.38% Frontal_Operculum_Cortex [-46.170103092783506, 28.273195876288668, -7.224226804123717]
# 152 78.97% Frontal_Orbital_Cortex; 18.35% Insular_Cortex [-32.07010309278351, 20.38350515463918, -16.0]
# 154 41.28% Frontal_Operculum_Cortex; 40.39% Insular_Cortex; 12.28% Frontal_Orbital_Cortex; 5.69% Inferior_Frontal_Gyrus_pars_triangularis [-32.47330960854093, 22.167259786476876, 5.882562277580064]
# 155 59.98% Inferior_Frontal_Gyrus_pars_opercularis; 29.99% Inferior_Frontal_Gyrus_pars_triangularis; 5.50% Frontal_Operculum_Cortex [-53.01553166069294, 18.46833930704898, 10.640382317801667]
# 156 50.95% Precentral_Gyrus; 27.86% Middle_Frontal_Gyrus; 21.19% Inferior_Frontal_Gyrus_pars_opercularis [-46.21428571428572, 7.923809523809524, 28.52380952380952]
# 176 68.85% Lateral_Occipital_Cortex_superior_division; 21.93% Superior_Parietal_Lobule; 7.48% Angular_Gyrus [-28.33025641025641, -62.47794871794872, 40.42461538461538]
# 191 52.60% Middle_Temporal_Gyrus_temporooccipital_part; 21.00% Supramarginal_Gyrus_posterior_division; 14.85% Middle_Temporal_Gyrus_posterior_division; 7.53% Superior_Temporal_Gyrus_posterior_division [-57.85547290116898, -47.52391073326248, 5.285866099893724]
# 198 43.70% Inferior_Temporal_Gyrus_temporooccipital_part; 24.81% Middle_Temporal_Gyrus_temporooccipital_part; 15.32% Middle_Temporal_Gyrus_posterior_division; 10.71% Inferior_Temporal_Gyrus_posterior_division [-60.389463781749754, -49.952963311382874, -14.090310442144869]
# 199 53.17% Temporal_Occipital_Fusiform_Cortex; 42.99% Inferior_Temporal_Gyrus_temporooccipital_part [-42.52488687782807, -52.230769230769226, -17.384615384615387]
# 200 47.58% Inferior_Temporal_Gyrus_posterior_division; 34.04% Temporal_Fusiform_Cortex_posterior_division; 16.83% Inferior_Temporal_Gyrus_temporooccipital_part [-46.61121856866538, -39.926499032882006, -24.20889748549323]
# 203 46.71% Lateral_Occipital_Cortex_superior_division; 32.88% Occipital_Pole; 20.40% Lateral_Occipital_Cortex_inferior_division [-31.693086003372684, -87.06576728499157, 12.516020236087684]
# 205 55.19% Lateral_Occipital_Cortex_inferior_division; 29.41% Occipital_Fusiform_Gyrus; 8.65% Temporal_Occipital_Fusiform_Cortex; 6.75% Inferior_Temporal_Gyrus_temporooccipital_part [-43.14384748700172, -70.4263431542461, -13.913344887348352]
# 206 39.92% Occipital_Fusiform_Gyrus; 36.69% Temporal_Occipital_Fusiform_Cortex; 23.39% Lingual_Gyrus [-25.91129032258064, -63.215053763440864, -12.244623655913976]
# 208 78.86% Lateral_Occipital_Cortex_inferior_division; 15.18% Middle_Temporal_Gyrus_temporooccipital_part; 5.84% Inferior_Temporal_Gyrus_temporooccipital_part [-48.17639429312581, -67.20622568093385, 0.9987029831387844]
# 209 80.83% Lateral_Occipital_Cortex_inferior_division; 10.06% Occipital_Fusiform_Gyrus; 9.11% Occipital_Pole [-35.99239543726236, -84.06083650190115, -3.9543726235741445]
# 212 52.00% Occipital_Fusiform_Gyrus; 34.15% Lingual_Gyrus; 13.03% Occipital_Pole [-14.564681724845997, -83.96714579055441, -12.991786447638603]
# 213 87.06% Occipital_Pole; 8.47% Lateral_Occipital_Cortex_inferior_division [-22.170015455950534, -96.75115919629057, -10.064914992272023]
# 235 100.00% no_label [-6.270935960591132, -66.27586206896552, -37.679802955665025]
# 239 100.00% no_label [-21.258196721311478, -70.02868852459017, -48.97540983606557]
# 240 54.24% no_label; 20.68% Occipital_Fusiform_Gyrus; 18.34% Lateral_Occipital_Cortex_inferior_division [-39.90829268292683, -74.51512195121951, -29.01073170731707]
# 241 100.00% no_label [-30.283559577677224, -80.12669683257919, -40.431372549019606]
# 245 100.00% no_label [-42.68720379146919, -63.74881516587678, -46.329383886255926]
# 246 80.45% no_label; 9.08% Occipital_Fusiform_Gyrus; 5.87% Lingual_Gyrus [-10.265363128491614, -81.69553072625698, -32.279329608938546]
# 251 98.43% no_label [-46.46234676007006, -46.85113835376532, -42.9492119089317]
# 252 94.62% no_label [-26.419106317411405, -69.58397534668721, -30.613251155624035]
# 255 74.89% no_label; 25.11% Brain-Stem [-24.260089686098652, -37.74887892376681, -44.24215246636771]
