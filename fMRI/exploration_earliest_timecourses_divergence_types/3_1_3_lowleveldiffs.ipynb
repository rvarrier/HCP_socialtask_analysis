# %% [markdown]
# # For any visualizations

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import scipy.stats as stats
from scipy.signal import resample

# %%
# setting default fontsizes for plots

s=16 # CHANGE FONTSIZE HERE

plt.rc('font', size=s) #controls default text size
plt.rc('axes', titlesize=s) #fontsize of the title
plt.rc('axes', labelsize=s) #fontsize of the x and y labels
plt.rc('xtick', labelsize=s) #fontsize of the x tick labels
plt.rc('ytick', labelsize=s) #fontsize of the y tick labels
plt.rc('legend', fontsize=s) #fontsize of the legend
plt.rcParams['savefig.facecolor']='white'
#import matplotlib as mpl
#mpl.rcParams['font.weight']= 'normal'

# %%
vid_names = ['COAXING-B', 'BILLIARD-A', 'DRIFTING-A', 'Fishing', 'RandomMechanical', 'Scaring','SEDUCING-B','STAR-A','SURPRISING-B','TENNIS-A']

# %%
plt.figure(1,figsize=(20,5))
for i,vid_name in enumerate(['COAXING-B','BILLIARD-A']):
    result_df = pd.read_csv('/Users/f0053cz/Dropbox (Dartmouth College)/postdoc_Dartmouth/HCP/social_stimuli/SOCIAL Stimuli/mp4/hcp10/csv/OptflowExtractor_' + vid_name + '.csv')
    #plt.subplot(2,1,i+1)
    plt.plot(result_df.onset,result_df.total_flow,label=vid_name)
    
plt.xlabel('Time (sec)')
plt.title('Optic flow')
#plt.ylim(0,400000)
plt.legend()


plt.figure(2,figsize=(20,5))
for i,vid_name in enumerate(['COAXING-B','BILLIARD-A']):
    result_df = pd.read_csv('/Users/f0053cz/Dropbox (Dartmouth College)/postdoc_Dartmouth/HCP/social_stimuli/SOCIAL Stimuli/mp4/hcp10/csv/BrightnessExtractor_' + vid_name + '.csv')
    #plt.subplot(2,1,i+1)
    plt.plot(result_df.onset,result_df.brightness,label=vid_name)
    #plt.ylim(0,400000)
plt.xlabel('Time (sec)')
plt.title('Brightness')
plt.legend()

# %%
result_df = pd.read_csv('/Users/f0053cz/Dropbox (Dartmouth College)/postdoc_Dartmouth/HCP/social_stimuli/SOCIAL Stimuli/mp4/hcp10/csv/OptflowExtractor_' + vid_names[0] + '.csv')
tc1 = result_df.total_flow
result_df = pd.read_csv('/Users/f0053cz/Dropbox (Dartmouth College)/postdoc_Dartmouth/HCP/social_stimuli/SOCIAL Stimuli/mp4/hcp10/csv/OptflowExtractor_' + vid_names[1] + '.csv')
tc2 = result_df.total_flow

# %%
#plt.plot(result_df.onset,result_df.total_flow,label=vid_name)
   
plt.figure(1,figsize=(10,5))
plt.plot(result_df.onset[:150],tc1,ls='None',marker = 'o',color='red', label ='COAX')
plt.plot(result_df.onset[:150],tc2,ls='None',marker = 'o',color='blue', label='BILL')
plt.xlabel('Time (sec)')
plt.title('Optic flow')
plt.legend(bbox_to_anchor=[1.01,1],fontsize=20)

stats.ttest_rel(tc1,tc2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c77352d12077> in <module>
#       2
#       3 plt.figure(1,figsize=(10,5))
# ----> 4 plt.plot(result_df.onset[:150],tc1,ls='None',marker = 'o',color='red', label ='COAX')
#       5 plt.plot(result_df.onset[:150],tc2,ls='None',marker = 'o',color='blue', label='BILL')
#       6 plt.xlabel('Time (sec)')
#
# NameError: name 'tc1' is not defined

# %%
result_df = pd.read_csv('/Users/f0053cz/Dropbox (Dartmouth College)/postdoc_Dartmouth/HCP/social_stimuli/SOCIAL Stimuli/mp4/hcp10/csv/OptflowExtractor_' + vid_name + '.csv')
result_df.head(10)
# Out:
#    order  duration     onset  object_id     total_flow
# 0    NaN  0.033333  0.000000          0      22.518429
# 1    NaN  0.033333  0.033333          0  274590.750000
# 2    NaN  0.033333  0.066667          0    1992.793000
# 3    NaN  0.033333  0.100000          0    1586.565800
# 4    NaN  0.033333  0.133333          0  275026.880000
# 5    NaN  0.033333  0.166667          0    2438.113300
# 6    NaN  0.033333  0.200000          0    3766.286600
# 7    NaN  0.033333  0.233333          0  275917.380000
# 8    NaN  0.033333  0.266667          0     457.397280
# 9    NaN  0.033333  0.300000          0     513.166200
