# %%
# to view surface plots (interactive) - can plot only one at a time in a cell
# 
log_scale = 0
from nilearn.plotting import view_surf
    
'''if log_scale == 0: # linear scale
    vmin,vmax = .72,20
    
    texture = surface.vol_to_surf(color_rois(nodes), fsaverage.pial_left)
    view_surf(fsaverage.infl_left, texture, vmin = vmin,vmax=vmax,
                            bg_map=fsaverage.sulc_left,cmap='Spectral',symmetric_cmap=False)

else:'''
# log scale
vmin,vmax =  np.log(.72),np.log(20)
texture = surface.vol_to_surf(color_rois(log_nodes_all_nocoaxbill), fsaverage.pial_left)
view_surf(fsaverage.infl_left, texture, vmin = vmin,vmax=vmax, threshold = .01,
                        bg_map=fsaverage.sulc_left,cmap=cmap,symmetric_cmap=False)

# %%
# DO NOT DELETE!! EXTRA CODE TO EXPLORE PLOTS AND TRY NEW SURF PLOT FUNCTIONS

# figuring out surfplots
#surf_plot.axes[1].get_yticklabels()
#surf_plot.axes[1].set_yticklabels([0,1,2,3,4])
#for i in surf_plot.get_axes():
#    print(type(i))
#from matplotlib.cm import ScalarMappable, get_cmap
#from matplotlib.colors import Normalize
#from matplotlib.colorbar import make_axes
'''ax_plot.axes[1].viewLim #gca().axes[0]
ax_plot.axes[0].get_ylabel()
ax_plot.axes[0].child_axes
vars(ax_plot.axes[1])'''

'''from nilearn.plotting import plot_surf_roi
vmin,vmax = .72,20
texture = surface.vol_to_surf(color_rois(nodes), fsaverage.pial_left)
figure, ax = plt.subplots(subplot_kw={'projection': '3d'})

ax_plot=plot_surf_roi(fsaverage.infl_left, texture, hemi='left',cmap = cmap, colorbar=True, vmax = vmax,vmin=vmin,
                            threshold=.72, bg_map=fsaverage.sulc_left,symmetric_cbar = False,axes=ax)'''




'''vmin,vmax = .72,20
texture = surface.vol_to_surf(color_rois(nodes), fsaverage.pial_left)
figure, ax = plt.subplots(subplot_kw={'projection': '3d'})

ax_plot=plot_surf_roi(fsaverage.infl_left, texture, hemi='left',cmap = cmap, colorbar=True, vmax = vmax,vmin=vmin,
                            threshold=.1, bg_map=fsaverage.sulc_left,symmetric_cbar = False,axes=ax)

vmin,vmax = np.log(.72),np.log(20)
texture = surface.vol_to_surf(color_rois(log_nodes_all_nocoaxbill), fsaverage.pial_left)
figure, ax = plt.subplots(subplot_kw={'projection': '3d'})

ax_plot=plot_surf_roi(fsaverage.infl_left, texture, hemi='left',cmap = cmap, colorbar=True, vmax = vmax,vmin=vmin,
                            threshold=.01, bg_map=fsaverage.sulc_left,symmetric_cbar = False,axes=ax)'''

#fig = plt.figure(1)
'''from nilearn.plotting import plot_surf_stat_map

vmin,vmax = .72,20
texture = surface.vol_to_surf(color_rois(nodes), fsaverage.pial_left)
figure, ax = plt.subplots(subplot_kw={'projection': '3d'})

ax_plot=plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = cmap, colorbar=False, vmax = vmax,
                            threshold=.72, bg_map=fsaverage.sulc_left,symmetric_cbar = False,axes=ax)'''

#ax_plot.axes[1].set_yticks(list(tks))
#ax_plot.axes[1].set_yticks(tks)
#ax_plot.gca()._cbar.set_ticks(tks)
#ax_plot._cbar.set_ticklabels(tklabels)

#ax_plot.gca().get_children()
#ax_plot.colorbar(ax_plot.gca())

'''#fig = plt.figure(1)
from nilearn.plotting import plot_surf_stat_map
tks = [.72,5,10,15,20]
tks = [np.log(i) for i in tks]
vmin,vmax = np.log(.72),np.log(20)
teaxture = surface.vol_to_surf(color_rois(log_nodes_all_nocoaxbill), fsaverage.pial_left)
ax_plot=plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = cmap, colorbar=True, vmax = vmax,
                            threshold=.01, bg_map=fsaverage.sulc_left,symmetric_cbar = False)

#fig = plt.figure(1)
vmin,vmax = .72,20
texture = surface.vol_to_surf(color_rois(nodes), fsaverage.pial_left)
ax_plot = plotting.plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = cmap, colorbar=True, vmax = vmax,
                            threshold=.72, bg_map=fsaverage.sulc_left,symmetric_cbar = False)

vmin,vmax =  np.log(.72),np.log(20)
texture = surface.vol_to_surf(color_rois(log_nodes_coaxbill), fsaverage.pial_left)
ax_plot = plotting.plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = 'Spectral', colorbar=True, vmax = vmax,
    vol_to_surf_kwargs={"kind": 'ball',"n_samples": 10, "radius": 10.0, "interpolation": "linear"},
                             threshold = .01,bg_map=fsaverage.sulc_left,symmetric_cbar = False)

vmin,vmax =  np.log(.72),np.log(20)
texture = surface.vol_to_surf(color_rois(log_nodes_coaxbill), fsaverage.pial_left)
ax_plot = plotting.plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = 'Spectral', colorbar=True, vmax = vmax,
                             threshold = .01,bg_map=fsaverage.sulc_left,symmetric_cbar = False)


'''

'''from nilearn import plotting,surface
#from nilearn import surface
#texture = surface.vol_to_surf(color_rois(log_nodes), fsaverage.pial_right)


# COAX-BILL
nodes = np.empty((268,))
nodes[:] = np.nan
node_inds = (nodes_coaxbill_rand_all) & (end_diff_coaxbill==1)
nodes[node_inds] = earliest_pt_coaxbill_corrected[node_inds]*TR

log_nodes_coaxbill = np.empty((268,))
log_nodes_coaxbill[:] = np.nan
log_nodes_coaxbill[~np.isnan(nodes)] = np.log(nodes[~np.isnan(nodes)])
log_nodes_coaxbill[np.isnan(log_nodes_coaxbill)] = 0

texture = surface.vol_to_surf(color_rois(log_nodes_coaxbill), fsaverage.pial_left)
ax_plot = plotting.plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = 'Spectral', colorbar=True,
                            threshold = .01, bg_map=fsaverage.sulc_left, vmax=vmax,vol_to_surf_kwargs={"n_samples": 1, "radius": 0.0, "interpolation": "nearest"},)

texture = surface.vol_to_surf(color_rois(nodes), fsaverage.pial_left)
ax_plot = plotting.plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = 'Spectral', colorbar=True,
                            threshold = .01, bg_map=fsaverage.sulc_left, vmax=vmax,vol_to_surf_kwargs={"n_samples": 1, "radius": 0.0, "interpolation": "nearest"},)

# alt. function
#img = roi_to_brain(pd.Series(log_nodes_coaxbill), mask_x)
#view_img_on_surf(img.to_nifti(),cmap = 'Spectral',symmetric_cmap=False, threshold=.01)



# CHANGE COLORBAR!!


ax_plot = plotting.plot_surf_stat_map(fsaverage.infl_left, texture, hemi='left',cmap = 'Spectral', colorbar=True,
                            threshold = .01, bg_map=fsaverage.sulc_left, vmax=vmax)
'''

# to view surface plots (interactive) - can plot only one at a time in a cell
# 
log_scale = 0
from nilearn.plotting import view_surf
    
'''if log_scale == 0: # linear scale
    vmin,vmax = .72,20
    
    texture = surface.vol_to_surf(color_rois(nodes), fsaverage.pial_left)
    view_surf(fsaverage.infl_left, texture, vmin = vmin,vmax=vmax,
                            bg_map=fsaverage.sulc_left,cmap='Spectral',symmetric_cmap=False)

else:'''
# log scale
vmin,vmax =  np.log(.72),np.log(20)
texture = surface.vol_to_surf(color_rois(log_nodes_all_nocoaxbill), fsaverage.pial_left)
view_surf(fsaverage.infl_left, texture, vmin = vmin,vmax=vmax, threshold = .01,
                        bg_map=fsaverage.sulc_left,cmap=cmap,symmetric_cmap=False)
